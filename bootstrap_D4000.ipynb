# %% [markdown]
# # IRC0218 (z = 1.62) Cluster & Field D4000 Comparison Study
# # by Jenn Cooper
# # Last modified 3 July 2018

# %%
run /Users/jennifercooper/bootstrap_err.py

# %%
fieldn(x,y,yer,lcb1,lcb2,lcb3,ucb1,ucb2,ucb3)
# Out:
# BCES, 10000 trials...
# 3.554124 s
# BCES, 10000 trials...
# 3.314281 s
# BCES, 10000 trials...
# 3.267440 s

# %%
ircn(x,y,yer,lcb1,lcb2,lcb3,ucb1,ucb2,ucb3)
# Out:
# BCES, 10000 trials...
# 3.205179 s
# BCES, 10000 trials...
# 3.266067 s
# BCES, 10000 trials...
# 3.351853 s
# BCES, 10000 trials...
# 3.213316 s

# %%
fieldr(x,y,yer,lcb1,lcb2,lcb3,ucb1,ucb2,ucb3)
# Out:
# [ 10.31  10.29  10.81  11.29  11.37  10.63  11.05]

# %%
ircr(x,y,yer,lcb1,lcb2,lcb3,ucb1,ucb2,ucb3)
# Out:
# BCES, 10000 trials...
# 3.281707 s
# BCES, 10000 trials...
# 3.242941 s
# BCES, 10000 trials...
# 3.191443 s
# BCES, 10000 trials...
# 3.270190 s

# %%
ircssmd(x,y,yer,lcb1,lcb2,lcb3,ucb1,ucb2,ucb3)
# Out:
# BCES, 10000 trials...
# 3.236274 s
# BCES, 10000 trials...
# 3.221998 s
# BCES, 10000 trials...
# 3.229011 s
# BCES, 10000 trials...
# 3.395239 s
